# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import time

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.svm import SVC

# %%
dataframe = pd.read_csv('CICIDS_DoS_2.csv')
dataframe.columns = dataframe.columns.str.strip()

# %%
selectedColumns = [
    'Dst Port', 'Total Length of Fwd Packet', 'Fwd Packet Length Max',
    'Fwd Packet Length Mean', 'Bwd Packet Length Max', 'Bwd Packet Length Min',
    'Bwd Packet Length Mean', 'Bwd Packet Length Std', 'Bwd IAT Total',
    'Bwd IAT Max', 'Packet Length Min', 'Packet Length Max', 'Packet Length Mean',
    'Packet Length Std', 'Packet Length Variance', 'SYN Flag Count', 'PSH Flag Count', 'URG Flag Count',
    'Average Packet Size', 'Fwd Segment Size Avg', 'Bwd Segment Size Avg',
    'Subflow Fwd Bytes', 'Label'
]

# %%
benignDataframe = dataframe[dataframe['Label'] == 'BENIGN']
benignDataframe = benignDataframe.iloc[:100000]

# %%
# check for duplicates in the subset of selected features
duplicates_mask = benignDataframe.duplicated(keep='first')
num_duplicates = duplicates_mask.sum()
print(f"Number of duplicate rows based on selected features: {num_duplicates}")

# remove duplicates directly
benignDataframe = benignDataframe.drop_duplicates(keep='first')
print(f"Shape of dataset after removing duplicates: {benignDataframe.shape}")

# select relevant columns 
benignDataframe = benignDataframe[selectedColumns]
benignDataframe
# Out:
# Number of duplicate rows based on selected features: 0
# Shape of dataset after removing duplicates: (100000, 91)
#         Dst Port  Total Length of Fwd Packet  Fwd Packet Length Max  \
# 0            443                           0                      0
# 1            443                           0                      0
# 2            443                           0                      0
# 3            443                           0                      0
# 4            443                           0                      0
# ...          ...                         ...                    ...
# 263533        53                          84                     42
# 263534       443                       11583                   1654
# 263535       123                          48                     48
# 263536        53                          68                     34
# 263537        53                          56                     56
#
#         Fwd Packet Length Mean  Bwd Packet Length Max  Bwd Packet Length Min  \
# 0                     0.000000                      0                      0
# 1                     0.000000                      0                      0
# 2                     0.000000                      0                      0
# 3                     0.000000                      0                      0
# 4                     0.000000                      0                      0
# ...                        ...                    ...                    ...
# 263533               42.000000                     95                     95
# 263534              609.631579                   1034                      0
# 263535               48.000000                     48                     48
# 263536               34.000000                     50                     50
# 263537               56.000000                     72                     72
#
#         Bwd Packet Length Mean  Bwd Packet Length Std  Bwd IAT Total  \
# 0                     0.000000               0.000000              0
# 1                     0.000000               0.000000              0
# 2                     0.000000               0.000000              0
# 3                     0.000000               0.000000              0
# 4                     0.000000               0.000000              0
# ...                        ...                    ...            ...
# 263533               95.000000               0.000000              3
# 263534              393.904762             514.532205      119994789
# 263535               48.000000               0.000000              0
# 263536               50.000000               0.000000              3
# 263537               72.000000               0.000000              0
#
#         Bwd IAT Max  ...  Packet Length Std  Packet Length Variance  \
# 0                 0  ...           0.000000                0.000000
# 1                 0  ...           0.000000                0.000000
# 2                 0  ...           0.000000                0.000000
# 3                 0  ...           0.000000                0.000000
# 4                 0  ...           0.000000                0.000000
# ...             ...  ...                ...                     ...
# 263533            3  ...          30.599564              936.333333
# 263534     10272554  ...         676.486765           457634.342949
# 263535            0  ...           0.000000                0.000000
# 263536            3  ...           9.237604               85.333333
# 263537            0  ...          11.313708              128.000000
#
#         SYN Flag Count  PSH Flag Count  URG Flag Count  Average Packet Size  \
# 0                    1               0               0                0.000
# 1                    1               0               0                0.000
# 2                    1               0               0                0.000
# 3                    1               0               0                0.000
# 4                    1               0               0                0.000
# ...                ...             ...             ...                  ...
# 263533               0               0               0               68.500
# 263534               0              15               0              496.375
# 263535               0               0               0               48.000
# 263536               0               0               0               42.000
# 263537               0               0               0               64.000
#
#         Fwd Segment Size Avg  Bwd Segment Size Avg  Subflow Fwd Bytes   Label
# 0                   0.000000              0.000000                  0  BENIGN
# 1                   0.000000              0.000000                  0  BENIGN
# 2                   0.000000              0.000000                  0  BENIGN
# 3                   0.000000              0.000000                  0  BENIGN
# 4                   0.000000              0.000000                  0  BENIGN
# ...                      ...                   ...                ...     ...
# 263533             42.000000             95.000000                 21  BENIGN
# 263534            609.631579            393.904762                289  BENIGN
# 263535             48.000000             48.000000                 24  BENIGN
# 263536             34.000000             50.000000                 17  BENIGN
# 263537             56.000000             72.000000                 28  BENIGN
#
# [100000 rows x 23 columns]

# %%
benignDataframe.shape
# Out:
# (100000, 23)

# %%
import random

# Create a new DataFrame with 100k rows, all values set to 0
new_rows = pd.DataFrame(0, index=range(100000), columns=benignDataframe.columns)

new_rows['Dst Port'] = random.randrange(0, 65535)
new_rows['SYN Flag Count'] = 1
new_rows['Bwd IAT Total'] = np.random.uniform(0.05, 2.5, 100000)
new_rows['Bwd IAT Max'] = np.random.uniform(0.05, 2.5, 100000)
new_rows['Label'] = 'DoS'

df = pd.concat([benignDataframe, new_rows], ignore_index=True)
df.tail(10)
# Out:
#         Dst Port  Total Length of Fwd Packet  Fwd Packet Length Max  \
# 199990     99991                           0                      0
# 199991     99992                           0                      0
# 199992     99993                           0                      0
# 199993     99994                           0                      0
# 199994     99995                           0                      0
# 199995     99996                           0                      0
# 199996     99997                           0                      0
# 199997     99998                           0                      0
# 199998     99999                           0                      0
# 199999    100000                           0                      0
#
#         Fwd Packet Length Mean  Bwd Packet Length Max  Bwd Packet Length Min  \
# 199990                     0.0                      0                      0
# 199991                     0.0                      0                      0
# 199992                     0.0                      0                      0
# 199993                     0.0                      0                      0
# 199994                     0.0                      0                      0
# 199995                     0.0                      0                      0
# 199996                     0.0                      0                      0
# 199997                     0.0                      0                      0
# 199998                     0.0                      0                      0
# 199999                     0.0                      0                      0
#
#         Bwd Packet Length Mean  Bwd Packet Length Std  Bwd IAT Total  \
# 199990                     0.0                    0.0       1.065703
# 199991                     0.0                    0.0       0.079261
# 199992                     0.0                    0.0       0.809124
# 199993                     0.0                    0.0       1.370376
# 199994                     0.0                    0.0       0.424415
# 199995                     0.0                    0.0       0.682916
# 199996                     0.0                    0.0       2.443729
# 199997                     0.0                    0.0       0.061574
# 199998                     0.0                    0.0       1.683340
# 199999                     0.0                    0.0       2.330913
#
#         Bwd IAT Max  ...  Packet Length Std  Packet Length Variance  \
# 199990     1.797706  ...                0.0                     0.0
# 199991     1.937256  ...                0.0                     0.0
# 199992     1.992616  ...                0.0                     0.0
# 199993     1.575269  ...                0.0                     0.0
# 199994     0.381265  ...                0.0                     0.0
# 199995     2.213969  ...                0.0                     0.0
# 199996     1.712988  ...                0.0                     0.0
# 199997     0.448410  ...                0.0                     0.0
# 199998     1.045264  ...                0.0                     0.0
# 199999     1.518370  ...                0.0                     0.0
#
#         SYN Flag Count  PSH Flag Count  URG Flag Count  Average Packet Size  \
# 199990               1               0               0                  0.0
# 199991               1               0               0                  0.0
# 199992               1               0               0                  0.0
# 199993               1               0               0                  0.0
# 199994               1               0               0                  0.0
# 199995               1               0               0                  0.0
# 199996               1               0               0                  0.0
# 199997               1               0               0                  0.0
# 199998               1               0               0                  0.0
# 199999               1               0               0                  0.0
#
#         Fwd Segment Size Avg  Bwd Segment Size Avg  Subflow Fwd Bytes  Label
# 199990                   0.0                   0.0                  0    DoS
# 199991                   0.0                   0.0                  0    DoS
# 199992                   0.0                   0.0                  0    DoS
# 199993                   0.0                   0.0                  0    DoS
# 199994                   0.0                   0.0                  0    DoS
# 199995                   0.0                   0.0                  0    DoS
# 199996                   0.0                   0.0                  0    DoS
# 199997                   0.0                   0.0                  0    DoS
# 199998                   0.0                   0.0                  0    DoS
# 199999                   0.0                   0.0                  0    DoS
#
# [10 rows x 23 columns]

# %%
df.shape
# Out:
# (200000, 23)

# %%
shuffled_df = df.sample(frac=1).reset_index(drop=True)

# %%
# Save the DataFrame to a CSV file
shuffled_df.to_csv('only_zeros.csv', index=False)
print("DataFrame saved to 'output.csv'")
# Out:
# DataFrame saved to 'output.csv'
